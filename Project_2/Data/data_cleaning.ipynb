# %%
import pandas as pd
print("done install pandas")
import json
# Out:
# done install pandas

# %%
# importing dataframe 
df = pd.read_csv('all_types_unclean.csv')
df.head()
df
# Out:
#                                          collectionsURL unitCode  \
# 0     https://collections.si.edu/search/detail/edanm...     SAAM
# 1     https://collections.si.edu/search/detail/edanm...     SAAM
# 2     https://collections.si.edu/search/detail/edanm...     SAAM
# 3     https://collections.si.edu/search/detail/edanm...     SAAM
# 4     https://collections.si.edu/search/detail/edanm...     SAAM
# ...                                                 ...      ...
# 3322  https://collections.si.edu/search/detail/edanm...     NMAH
# 3323  https://collections.si.edu/search/detail/edanm...     NMAH
# 3324  https://collections.si.edu/search/detail/edanm...     NMAH
# 3325  https://collections.si.edu/search/detail/edanm...     NMAH
# 3326  https://collections.si.edu/search/detail/edanm...     NMAH
#
#                                dataSource  \
# 0         Smithsonian American Art Museum
# 1         Smithsonian American Art Museum
# 2         Smithsonian American Art Museum
# 3         Smithsonian American Art Museum
# 4         Smithsonian American Art Museum
# ...                                   ...
# 3322  National Museum of American History
# 3323  National Museum of American History
# 3324  National Museum of American History
# 3325  National Museum of American History
# 3326  National Museum of American History
#
#                                                   title  \
# 0                                     George Washington
# 1              Portrait of Thayendanegea (Joseph Brant)
# 2     The Davis Children (Eliza Cheever Davis and Jo...
# 3                               Portrait of a Gentleman
# 4                                         John Swanwick
# ...                                                 ...
# 3322                                    William Wissing
# 3323                                  Guillaume Du Vair
# 3324                                  Portrait of a Boy
# 3325                                    Christian Weise
# 3326                                          Mona Lisa
#
#                       EDANid  \
# 0        edanmdm:saam_XX108A
# 1       edanmdm:saam_2024.24
# 2     edanmdm:saam_2019.6.12
# 3       edanmdm:saam_2012.21
# 4     edanmdm:saam_2010.16.2
# ...                      ...
# 3322    edanmdm:nmah_1002735
# 3323    edanmdm:nmah_1002731
# 3324    edanmdm:nmah_1002729
# 3325    edanmdm:nmah_1002727
# 3326    edanmdm:nmah_1002720
#
#                                                    guid  \
# 0     http://n2t.net/ark:/65665/vk7c06aa8a1-8da1-47c...
# 1     http://n2t.net/ark:/65665/vk73fdea64c-bcb4-4a4...
# 2     http://n2t.net/ark:/65665/vk7db2de5a6-554f-456...
# 3     http://n2t.net/ark:/65665/vk79241bdef-7f0c-441...
# 4     http://n2t.net/ark:/65665/vk73f915b19-cb1a-4db...
# ...                                                 ...
# 3322  https://n2t.net/ark:/65665/ng49ca746a8-8fdf-70...
# 3323  https://n2t.net/ark:/65665/ng49ca746ad-c883-70...
# 3324  https://n2t.net/ark:/65665/ng49ca746a8-8ecd-70...
# 3325  https://n2t.net/ark:/65665/ng49ca746a8-8ec7-70...
# 3326  https://n2t.net/ark:/65665/ng49ca746ad-de0e-70...
#
#                                              recordLink lastUpdateDate  \
# 0     https://americanart.si.edu/collections/search/...     2024-11-22
# 1     https://americanart.si.edu/collections/search/...     2025-01-16
# 2     https://americanart.si.edu/collections/search/...     2024-11-22
# 3     https://americanart.si.edu/collections/search/...     2024-11-22
# 4     https://americanart.si.edu/collections/search/...     2024-11-22
# ...                                                 ...            ...
# 3322                                                NaN     2024-10-16
# 3323                                                NaN     2024-11-22
# 3324                                                NaN     2024-10-16
# 3325                                                NaN     2024-11-22
# 3326                                                NaN     2024-11-22
#
#                                              creditLine  \
# 0     {"Credit Line": "Smithsonian American Art Muse...
# 1     {"Credit Line": "Smithsonian American Art Muse...
# 2     {"Credit Line": "Smithsonian American Art Muse...
# 3     {"Credit Line": "Smithsonian American Art Muse...
# 4     {"Credit Line": "Smithsonian American Art Muse...
# ...                                                 ...
# 3322                                                NaN
# 3323                                                NaN
# 3324                                                NaN
# 3325                                                NaN
# 3326                                                NaN
#
#                                date  ... publisher  \
# 0                 {"Date": "1803?"}  ...       NaN
# 1            {"Date": "after 1797"}  ...       NaN
# 2                  {"Date": "1795"}  ...       NaN
# 3                  {"Date": "1793"}  ...       NaN
# 4              {"Date": "ca. 1800"}  ...       NaN
# ...                             ...  ...       ...
# 3322  {"date made": "18th century"}  ...       NaN
# 3323  {"date made": "18th century"}  ...       NaN
# 3324          {"Date made": "1778"}  ...       NaN
# 3325  {"date made": "18th century"}  ...       NaN
# 3326  {"date made": "ca 1803-1809"}  ...       NaN
#
#                                                   topic   indexed_dates  \
# 0     {"Topic": "Occupation\\political\\president\nP...         [1800s]
# 1                            {"Topic": "Portrait male"}         [1790s]
# 2     {"Topic": "Landscape\nObject\\flower\\lily\nPo...         [1790s]
# 3                      {"Topic": "Portrait male\\bust"}         [1790s]
# 4     {"Topic": "Object\\written matter\\book\nPortr...  [1800s, 1790s]
# ...                                                 ...             ...
# 3322                           {"Subject": "Portraits"}         [1800s]
# 3323                           {"Subject": "Portraits"}         [1800s]
# 3324                           {"Subject": "Portraits"}         [1770s]
# 3325                           {"Subject": "Portraits"}         [1800s]
# 3326                           {"Subject": "Portraits"}         [1800s]
#
#                                           indexed_names  \
# 0         ['Washington, George', 'Winstanley, William']
# 1             ['Peale, Charles Willson', Portrait male]
# 2     ['Savage, Edward', 'Davis, Eliza Cheever', 'Da...
# 3                                      ['Peale, James']
# 4                  ['Pratt, Matthew', 'Swanwick, John']
# ...                                                 ...
# 3322                                ['Walker, Anthony']
# 3323                                  ['Lamsvelt, Jan']
# 3324  ['Netscher, Caspar', Basan & Poignant, 'Hemery...
# 3325                            ['Bernigeroth, Martin']
# 3326  ['Bouillon, Pierre', 'da Vinci, Leonardo', 'Ma...
#
#                  indexed_object_types                     indexed_places  \
# 0                         [Paintings]                                 []
# 1                         [Paintings]                                 []
# 2                         [Paintings]                                 []
# 3                         [Paintings]                                 []
# 4                         [Paintings]                                 []
# ...                               ...                                ...
# 3322  ['Engravings (prints)', Prints]  [England, London, United Kingdom]
# 3323  ['Engravings (prints)', Prints]                                 []
# 3324  ['Engravings (prints)', Prints]                                 []
# 3325  ['Engravings (prints)', Prints]                                 []
# 3326  ['Engravings (prints)', Prints]     [Île-de-France, France, Paris]
#
#                                          indexed_topics mediaCount  \
# 0     [Occupations, Men, Portraits, Political, Presi...          1
# 1                                      [Men, Portraits]          0
# 2     [Women, Landscapes, Men, Portraits, Flowers, C...          1
# 3                                      [Men, Portraits]          1
# 4                   [Books and reading, Men, Portraits]          1
# ...                                                 ...        ...
# 3322                                   [Art, Portraits]          0
# 3323                                   [Art, Portraits]          0
# 3324                                   [Art, Portraits]          0
# 3325                                   [Art, Portraits]          0
# 3326                                   [Art, Portraits]          0
#
#                                               mediaURLs  \
# 0     ['https://ids.si.edu/ids/deliveryService?id=SA...
# 1                                                    []
# 2     ['https://ids.si.edu/ids/deliveryService?id=SA...
# 3     ['https://ids.si.edu/ids/deliveryService?id=SA...
# 4     ['https://ids.si.edu/ids/deliveryService?id=SA...
# ...                                                 ...
# 3322                                                 []
# 3323                                                 []
# 3324                                                 []
# 3325                                                 []
# 3326                                                 []
#
#                                               thumbnail
# 0     https://ids.si.edu/ids/iiif/SAAM-XX108A_1/full...
# 1                                                   NaN
# 2     https://ids.si.edu/ids/iiif/SAAM-2019.6.12_1/f...
# 3     https://ids.si.edu/ids/iiif/SAAM-2012.21_1/ful...
# 4     https://ids.si.edu/ids/iiif/SAAM-2010.16.2_1/f...
# ...                                                 ...
# 3322                                                NaN
# 3323                                                NaN
# 3324                                                NaN
# 3325                                                NaN
# 3326                                                NaN
#
# [3327 rows x 26 columns]

# %%
df.iloc[0]
df["name"][0]
print(type(df["name"][0]))
print(df["name"][0])
df.head()
# Out:
# <class 'str'>
# {"Attributed to": "William Winstanley, born England, active 1775-1806", "Sitter": "George Washington"}
#                                       collectionsURL unitCode  \
# 0  https://collections.si.edu/search/detail/edanm...     SAAM
# 1  https://collections.si.edu/search/detail/edanm...     SAAM
# 2  https://collections.si.edu/search/detail/edanm...     SAAM
# 3  https://collections.si.edu/search/detail/edanm...     SAAM
# 4  https://collections.si.edu/search/detail/edanm...     SAAM
#
#                         dataSource  \
# 0  Smithsonian American Art Museum
# 1  Smithsonian American Art Museum
# 2  Smithsonian American Art Museum
# 3  Smithsonian American Art Museum
# 4  Smithsonian American Art Museum
#
#                                                title                  EDANid  \
# 0                                  George Washington     edanmdm:saam_XX108A
# 1           Portrait of Thayendanegea (Joseph Brant)    edanmdm:saam_2024.24
# 2  The Davis Children (Eliza Cheever Davis and Jo...  edanmdm:saam_2019.6.12
# 3                            Portrait of a Gentleman    edanmdm:saam_2012.21
# 4                                      John Swanwick  edanmdm:saam_2010.16.2
#
#                                                 guid  \
# 0  http://n2t.net/ark:/65665/vk7c06aa8a1-8da1-47c...
# 1  http://n2t.net/ark:/65665/vk73fdea64c-bcb4-4a4...
# 2  http://n2t.net/ark:/65665/vk7db2de5a6-554f-456...
# 3  http://n2t.net/ark:/65665/vk79241bdef-7f0c-441...
# 4  http://n2t.net/ark:/65665/vk73f915b19-cb1a-4db...
#
#                                           recordLink lastUpdateDate  \
# 0  https://americanart.si.edu/collections/search/...     2024-11-22
# 1  https://americanart.si.edu/collections/search/...     2025-01-16
# 2  https://americanart.si.edu/collections/search/...     2024-11-22
# 3  https://americanart.si.edu/collections/search/...     2024-11-22
# 4  https://americanart.si.edu/collections/search/...     2024-11-22
#
#                                           creditLine                    date  \
# 0  {"Credit Line": "Smithsonian American Art Muse...       {"Date": "1803?"}
# 1  {"Credit Line": "Smithsonian American Art Muse...  {"Date": "after 1797"}
# 2  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1795"}
# 3  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1793"}
# 4  {"Credit Line": "Smithsonian American Art Muse...    {"Date": "ca. 1800"}
#
#    ... publisher                                              topic  \
# 0  ...       NaN  {"Topic": "Occupation\\political\\president\nP...
# 1  ...       NaN                         {"Topic": "Portrait male"}
# 2  ...       NaN  {"Topic": "Landscape\nObject\\flower\\lily\nPo...
# 3  ...       NaN                   {"Topic": "Portrait male\\bust"}
# 4  ...       NaN  {"Topic": "Object\\written matter\\book\nPortr...
#
#     indexed_dates                                      indexed_names  \
# 0         [1800s]      ['Washington, George', 'Winstanley, William']
# 1         [1790s]          ['Peale, Charles Willson', Portrait male]
# 2         [1790s]  ['Savage, Edward', 'Davis, Eliza Cheever', 'Da...
# 3         [1790s]                                   ['Peale, James']
# 4  [1800s, 1790s]               ['Pratt, Matthew', 'Swanwick, John']
#
#   indexed_object_types indexed_places  \
# 0          [Paintings]             []
# 1          [Paintings]             []
# 2          [Paintings]             []
# 3          [Paintings]             []
# 4          [Paintings]             []
#
#                                       indexed_topics mediaCount  \
# 0  [Occupations, Men, Portraits, Political, Presi...          1
# 1                                   [Men, Portraits]          0
# 2  [Women, Landscapes, Men, Portraits, Flowers, C...          1
# 3                                   [Men, Portraits]          1
# 4                [Books and reading, Men, Portraits]          1
#
#                                            mediaURLs  \
# 0  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 1                                                 []
# 2  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 3  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 4  ['https://ids.si.edu/ids/deliveryService?id=SA...
#
#                                            thumbnail
# 0  https://ids.si.edu/ids/iiif/SAAM-XX108A_1/full...
# 1                                                NaN
# 2  https://ids.si.edu/ids/iiif/SAAM-2019.6.12_1/f...
# 3  https://ids.si.edu/ids/iiif/SAAM-2012.21_1/ful...
# 4  https://ids.si.edu/ids/iiif/SAAM-2010.16.2_1/f...
#
# [5 rows x 26 columns]

# %%
#Extract from ["name"] column and add to new "Sitter" Column
df["Sitter"] = df["name"].str.extract(r'"Sitter"\s*:\s*"([^"]*)"')
#add artist column
df["Artist"] = df["name"].str.extract(
    r'"Artist"\s*:\s*"([^"]*)"|'
    r'"Attributed to"\s*:\s*"([^"]*)"|'
    r'"Attribution"\s*:\s*"([^"]*)"|'
    r'"Engraver"\s*:\s*"([^"]*)"'
).bfill(axis=1).iloc[:, 0]
#extract date from date column
df["Clean_Date"] = df["date"].str.extract(r'"Date"\s*:\s*"([^"]*)"')

import re
#extract gender from indexecd_topics
# df["Gender"] = df["indexed_topics"].str.extract(r'(Men|Women)', flags=re.IGNORECASE)
#extract occupations from topic
#df["Occupation"] = df["indexed_topics"].str.extract(r'(Scientists|Artists|Writers|Politicians|Philosophers|Religious Figures|Businesspeople|Athletes|Musicians|Actors|Military Figures)', flags=re.IGNORECASE)

print("done")
df.head()
# Out:
# done
#                                       collectionsURL unitCode  \
# 0  https://collections.si.edu/search/detail/edanm...     SAAM
# 1  https://collections.si.edu/search/detail/edanm...     SAAM
# 2  https://collections.si.edu/search/detail/edanm...     SAAM
# 3  https://collections.si.edu/search/detail/edanm...     SAAM
# 4  https://collections.si.edu/search/detail/edanm...     SAAM
#
#                         dataSource  \
# 0  Smithsonian American Art Museum
# 1  Smithsonian American Art Museum
# 2  Smithsonian American Art Museum
# 3  Smithsonian American Art Museum
# 4  Smithsonian American Art Museum
#
#                                                title                  EDANid  \
# 0                                  George Washington     edanmdm:saam_XX108A
# 1           Portrait of Thayendanegea (Joseph Brant)    edanmdm:saam_2024.24
# 2  The Davis Children (Eliza Cheever Davis and Jo...  edanmdm:saam_2019.6.12
# 3                            Portrait of a Gentleman    edanmdm:saam_2012.21
# 4                                      John Swanwick  edanmdm:saam_2010.16.2
#
#                                                 guid  \
# 0  http://n2t.net/ark:/65665/vk7c06aa8a1-8da1-47c...
# 1  http://n2t.net/ark:/65665/vk73fdea64c-bcb4-4a4...
# 2  http://n2t.net/ark:/65665/vk7db2de5a6-554f-456...
# 3  http://n2t.net/ark:/65665/vk79241bdef-7f0c-441...
# 4  http://n2t.net/ark:/65665/vk73f915b19-cb1a-4db...
#
#                                           recordLink lastUpdateDate  \
# 0  https://americanart.si.edu/collections/search/...     2024-11-22
# 1  https://americanart.si.edu/collections/search/...     2025-01-16
# 2  https://americanart.si.edu/collections/search/...     2024-11-22
# 3  https://americanart.si.edu/collections/search/...     2024-11-22
# 4  https://americanart.si.edu/collections/search/...     2024-11-22
#
#                                           creditLine                    date  \
# 0  {"Credit Line": "Smithsonian American Art Muse...       {"Date": "1803?"}
# 1  {"Credit Line": "Smithsonian American Art Muse...  {"Date": "after 1797"}
# 2  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1795"}
# 3  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1793"}
# 4  {"Credit Line": "Smithsonian American Art Muse...    {"Date": "ca. 1800"}
#
#    ...                                      indexed_names  \
# 0  ...      ['Washington, George', 'Winstanley, William']
# 1  ...          ['Peale, Charles Willson', Portrait male]
# 2  ...  ['Savage, Edward', 'Davis, Eliza Cheever', 'Da...
# 3  ...                                   ['Peale, James']
# 4  ...               ['Pratt, Matthew', 'Swanwick, John']
#
#   indexed_object_types indexed_places  \
# 0          [Paintings]             []
# 1          [Paintings]             []
# 2          [Paintings]             []
# 3          [Paintings]             []
# 4          [Paintings]             []
#
#                                       indexed_topics mediaCount  \
# 0  [Occupations, Men, Portraits, Political, Presi...          1
# 1                                   [Men, Portraits]          0
# 2  [Women, Landscapes, Men, Portraits, Flowers, C...          1
# 3                                   [Men, Portraits]          1
# 4                [Books and reading, Men, Portraits]          1
#
#                                            mediaURLs  \
# 0  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 1                                                 []
# 2  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 3  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 4  ['https://ids.si.edu/ids/deliveryService?id=SA...
#
#                                            thumbnail  \
# 0  https://ids.si.edu/ids/iiif/SAAM-XX108A_1/full...
# 1                                                NaN
# 2  https://ids.si.edu/ids/iiif/SAAM-2019.6.12_1/f...
# 3  https://ids.si.edu/ids/iiif/SAAM-2012.21_1/ful...
# 4  https://ids.si.edu/ids/iiif/SAAM-2010.16.2_1/f...
#
#                                   Sitter  \
# 0                      George Washington
# 1                          Portrait male
# 2  Eliza Cheever Davis\nJohn Derby Davis
# 3                           unidentified
# 4                          John Swanwick
#
#                                               Artist  Clean_Date
# 0  William Winstanley, born England, active 1775-...       1803?
# 1                                       Unidentified  after 1797
# 2  Edward Savage, born Princeton, MA 1761-died Pr...        1795
# 3  James Peale, born Chestertown, MD 1749-died Ph...        1793
# 4  Matthew Pratt, born Philadelphia, PA 1734-died...    ca. 1800
#
# [5 rows x 29 columns]

# %%
#Drop NAs
df = df[df["Sitter"].notna()].reset_index(drop=True)
#remove dates from end of some names
df["Sitter"] = df["Sitter"].str.split(",", n=1).str[0].str.strip()
#remove extraneous info from the end of some artists
df["Artist"] = df["Artist"].str.split(",", n = 1).str[0].str.strip()
#only keep numbers in Clean_Date
df["Clean_Date"] = df["Clean_Date"].astype(str).str.extract('(\d+)').astype(int)

df["Clean_Date"]


# df.to_csv("check_dates.csv")
# df.head()
df.head()
# Out:
#                                       collectionsURL unitCode  \
# 0  https://collections.si.edu/search/detail/edanm...     SAAM
# 1  https://collections.si.edu/search/detail/edanm...     SAAM
# 2  https://collections.si.edu/search/detail/edanm...     SAAM
# 3  https://collections.si.edu/search/detail/edanm...     SAAM
# 4  https://collections.si.edu/search/detail/edanm...     SAAM
#
#                         dataSource  \
# 0  Smithsonian American Art Museum
# 1  Smithsonian American Art Museum
# 2  Smithsonian American Art Museum
# 3  Smithsonian American Art Museum
# 4  Smithsonian American Art Museum
#
#                                                title                  EDANid  \
# 0                                  George Washington     edanmdm:saam_XX108A
# 1           Portrait of Thayendanegea (Joseph Brant)    edanmdm:saam_2024.24
# 2  The Davis Children (Eliza Cheever Davis and Jo...  edanmdm:saam_2019.6.12
# 3                            Portrait of a Gentleman    edanmdm:saam_2012.21
# 4                                      John Swanwick  edanmdm:saam_2010.16.2
#
#                                                 guid  \
# 0  http://n2t.net/ark:/65665/vk7c06aa8a1-8da1-47c...
# 1  http://n2t.net/ark:/65665/vk73fdea64c-bcb4-4a4...
# 2  http://n2t.net/ark:/65665/vk7db2de5a6-554f-456...
# 3  http://n2t.net/ark:/65665/vk79241bdef-7f0c-441...
# 4  http://n2t.net/ark:/65665/vk73f915b19-cb1a-4db...
#
#                                           recordLink lastUpdateDate  \
# 0  https://americanart.si.edu/collections/search/...     2024-11-22
# 1  https://americanart.si.edu/collections/search/...     2025-01-16
# 2  https://americanart.si.edu/collections/search/...     2024-11-22
# 3  https://americanart.si.edu/collections/search/...     2024-11-22
# 4  https://americanart.si.edu/collections/search/...     2024-11-22
#
#                                           creditLine                    date  \
# 0  {"Credit Line": "Smithsonian American Art Muse...       {"Date": "1803?"}
# 1  {"Credit Line": "Smithsonian American Art Muse...  {"Date": "after 1797"}
# 2  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1795"}
# 3  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1793"}
# 4  {"Credit Line": "Smithsonian American Art Muse...    {"Date": "ca. 1800"}
#
#    ...                                      indexed_names  \
# 0  ...      ['Washington, George', 'Winstanley, William']
# 1  ...          ['Peale, Charles Willson', Portrait male]
# 2  ...  ['Savage, Edward', 'Davis, Eliza Cheever', 'Da...
# 3  ...                                   ['Peale, James']
# 4  ...               ['Pratt, Matthew', 'Swanwick, John']
#
#   indexed_object_types indexed_places  \
# 0          [Paintings]             []
# 1          [Paintings]             []
# 2          [Paintings]             []
# 3          [Paintings]             []
# 4          [Paintings]             []
#
#                                       indexed_topics mediaCount  \
# 0  [Occupations, Men, Portraits, Political, Presi...          1
# 1                                   [Men, Portraits]          0
# 2  [Women, Landscapes, Men, Portraits, Flowers, C...          1
# 3                                   [Men, Portraits]          1
# 4                [Books and reading, Men, Portraits]          1
#
#                                            mediaURLs  \
# 0  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 1                                                 []
# 2  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 3  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 4  ['https://ids.si.edu/ids/deliveryService?id=SA...
#
#                                            thumbnail  \
# 0  https://ids.si.edu/ids/iiif/SAAM-XX108A_1/full...
# 1                                                NaN
# 2  https://ids.si.edu/ids/iiif/SAAM-2019.6.12_1/f...
# 3  https://ids.si.edu/ids/iiif/SAAM-2012.21_1/ful...
# 4  https://ids.si.edu/ids/iiif/SAAM-2010.16.2_1/f...
#
#                                   Sitter              Artist Clean_Date
# 0                      George Washington  William Winstanley       1803
# 1                          Portrait male        Unidentified       1797
# 2  Eliza Cheever Davis\nJohn Derby Davis       Edward Savage       1795
# 3                           unidentified         James Peale       1793
# 4                          John Swanwick       Matthew Pratt       1800
#
# [5 rows x 29 columns]

# %%
#Export here:
df.to_csv("cleaned.csv", index=False)

# %%
#summary df
sitter_counts = df["Sitter"].value_counts().reset_index()
sitter_counts.columns = ["Sitter", "Count"]
print(sitter_counts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 #summary df
# ----> 2 sitter_counts = df["Sitter"].value_counts().reset_index()
#       3 sitter_counts.columns = ["Sitter", "Count"]
#       4 print(sitter_counts)
#
# NameError: name 'df' is not defined

# %%
sitter_counts.to_csv("sitter_counts_test.csv")

# %% [markdown]
# Take cleaned.csv and remove sitters not used for project 2

# %%
clean_before_removal = pd.read_csv("cleaned.csv")
clean_before_removal.head()
# Out:
#                                       collectionsURL unitCode  \
# 0  https://collections.si.edu/search/detail/edanm...     SAAM
# 1  https://collections.si.edu/search/detail/edanm...     SAAM
# 2  https://collections.si.edu/search/detail/edanm...     SAAM
# 3  https://collections.si.edu/search/detail/edanm...     SAAM
# 4  https://collections.si.edu/search/detail/edanm...     SAAM
#
#                         dataSource  \
# 0  Smithsonian American Art Museum
# 1  Smithsonian American Art Museum
# 2  Smithsonian American Art Museum
# 3  Smithsonian American Art Museum
# 4  Smithsonian American Art Museum
#
#                                                title                  EDANid  \
# 0                                  George Washington     edanmdm:saam_XX108A
# 1           Portrait of Thayendanegea (Joseph Brant)    edanmdm:saam_2024.24
# 2  The Davis Children (Eliza Cheever Davis and Jo...  edanmdm:saam_2019.6.12
# 3                            Portrait of a Gentleman    edanmdm:saam_2012.21
# 4                                      John Swanwick  edanmdm:saam_2010.16.2
#
#                                                 guid  \
# 0  http://n2t.net/ark:/65665/vk7c06aa8a1-8da1-47c...
# 1  http://n2t.net/ark:/65665/vk73fdea64c-bcb4-4a4...
# 2  http://n2t.net/ark:/65665/vk7db2de5a6-554f-456...
# 3  http://n2t.net/ark:/65665/vk79241bdef-7f0c-441...
# 4  http://n2t.net/ark:/65665/vk73f915b19-cb1a-4db...
#
#                                           recordLink lastUpdateDate  \
# 0  https://americanart.si.edu/collections/search/...     2024-11-22
# 1  https://americanart.si.edu/collections/search/...     2025-01-16
# 2  https://americanart.si.edu/collections/search/...     2024-11-22
# 3  https://americanart.si.edu/collections/search/...     2024-11-22
# 4  https://americanart.si.edu/collections/search/...     2024-11-22
#
#                                           creditLine                    date  \
# 0  {"Credit Line": "Smithsonian American Art Muse...       {"Date": "1803?"}
# 1  {"Credit Line": "Smithsonian American Art Muse...  {"Date": "after 1797"}
# 2  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1795"}
# 3  {"Credit Line": "Smithsonian American Art Muse...        {"Date": "1793"}
# 4  {"Credit Line": "Smithsonian American Art Muse...    {"Date": "ca. 1800"}
#
#    ...                                      indexed_names  \
# 0  ...      ['Washington, George', 'Winstanley, William']
# 1  ...          ['Peale, Charles Willson', Portrait male]
# 2  ...  ['Savage, Edward', 'Davis, Eliza Cheever', 'Da...
# 3  ...                                   ['Peale, James']
# 4  ...               ['Pratt, Matthew', 'Swanwick, John']
#
#   indexed_object_types indexed_places  \
# 0          [Paintings]             []
# 1          [Paintings]             []
# 2          [Paintings]             []
# 3          [Paintings]             []
# 4          [Paintings]             []
#
#                                       indexed_topics mediaCount  \
# 0  [Occupations, Men, Portraits, Political, Presi...          1
# 1                                   [Men, Portraits]          0
# 2  [Women, Landscapes, Men, Portraits, Flowers, C...          1
# 3                                   [Men, Portraits]          1
# 4                [Books and reading, Men, Portraits]          1
#
#                                            mediaURLs  \
# 0  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 1                                                 []
# 2  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 3  ['https://ids.si.edu/ids/deliveryService?id=SA...
# 4  ['https://ids.si.edu/ids/deliveryService?id=SA...
#
#                                            thumbnail  \
# 0  https://ids.si.edu/ids/iiif/SAAM-XX108A_1/full...
# 1                                                NaN
# 2  https://ids.si.edu/ids/iiif/SAAM-2019.6.12_1/f...
# 3  https://ids.si.edu/ids/iiif/SAAM-2012.21_1/ful...
# 4  https://ids.si.edu/ids/iiif/SAAM-2010.16.2_1/f...
#
#                                   Sitter              Artist Clean_Date
# 0                      George Washington  William Winstanley       1803
# 1                          Portrait male        Unidentified       1797
# 2  Eliza Cheever Davis\nJohn Derby Davis       Edward Savage       1795
# 3                           unidentified         James Peale       1793
# 4                          John Swanwick       Matthew Pratt       1800
#
# [5 rows x 29 columns]

# %%
sitters_to_keep = ["George Washington",
    "Benjamin Franklin",
    "Thomas Jefferson",
    "John Adams",
    "Alexander Hamilton",
    "James Madison"
]
cleaned_test = clean_before_removal[clean_before_removal["Sitter"].isin(sitters_to_keep)].reset_index(drop=True)

# %%
print(cleaned_test["Sitter"].value_counts())
cleaned_test
# Out:
# Sitter
# George Washington     84
# Benjamin Franklin     26
# Thomas Jefferson      23
# John Adams            10
# Alexander Hamilton     8
# James Madison          6
# Name: count, dtype: int64
#                                         collectionsURL unitCode  \
# 0    https://collections.si.edu/search/detail/edanm...     SAAM
# 1    https://collections.si.edu/search/detail/edanm...     SAAM
# 2    https://collections.si.edu/search/detail/edanm...     SAAM
# 3    https://collections.si.edu/search/detail/edanm...      NPG
# 4    https://collections.si.edu/search/detail/edanm...      NPG
# ..                                                 ...      ...
# 152  https://collections.si.edu/search/detail/edanm...      NPG
# 153  https://collections.si.edu/search/detail/edanm...      NPG
# 154  https://collections.si.edu/search/detail/edanm...      NPG
# 155  https://collections.si.edu/search/detail/edanm...      NPG
# 156  https://collections.si.edu/search/detail/edanm...      NPG
#
#                           dataSource                                   title  \
# 0    Smithsonian American Art Museum                       George Washington
# 1    Smithsonian American Art Museum    Mourning Piece for George Washington
# 2    Smithsonian American Art Museum                       George Washington
# 3          National Portrait Gallery                       Benjamin Franklin
# 4          National Portrait Gallery                       George Washington
# ..                               ...                                     ...
# 152        National Portrait Gallery                      Alexander Hamilton
# 153        National Portrait Gallery                       George Washington
# 154        National Portrait Gallery                        Thomas Jefferson
# 155        National Portrait Gallery                       George Washington
# 156        National Portrait Gallery  George Washington (Lansdowne Portrait)
#
#                           EDANid  \
# 0            edanmdm:saam_XX108A
# 1          edanmdm:saam_1971.111
# 2          edanmdm:saam_1971.102
# 3       edanmdm:npg_S_NPG.87.222
# 4       edanmdm:npg_S_NPG.85.297
# ..                           ...
# 152      edanmdm:npg_NPG.2003.72
# 153     edanmdm:npg_NPG.2002.384
# 154  edanmdm:npg_NPG.2002.184.62
# 155   edanmdm:npg_NPG.2002.184.5
# 156      edanmdm:npg_NPG.2001.13
#
#                                                   guid  \
# 0    http://n2t.net/ark:/65665/vk7c06aa8a1-8da1-47c...
# 1    http://n2t.net/ark:/65665/vk7b2f8e20a-81fb-4f2...
# 2    http://n2t.net/ark:/65665/vk74652dc00-4f71-488...
# 3    http://n2t.net/ark:/65665/sm4c77a42c7-3a26-4b6...
# 4    http://n2t.net/ark:/65665/sm4b8e95381-ee00-454...
# ..                                                 ...
# 152  http://n2t.net/ark:/65665/sm4e9c8bb92-5e05-4d8...
# 153  http://n2t.net/ark:/65665/sm4c1771bc3-446a-466...
# 154  http://n2t.net/ark:/65665/sm4675cd41c-80fe-4a7...
# 155  http://n2t.net/ark:/65665/sm414b2a532-95ef-4a6...
# 156  http://n2t.net/ark:/65665/sm46a76a395-dbbe-4e5...
#
#                                             recordLink lastUpdateDate  \
# 0    https://americanart.si.edu/collections/search/...     2024-11-22
# 1    https://americanart.si.edu/collections/search/...     2024-11-22
# 2    https://americanart.si.edu/collections/search/...     2024-11-22
# 3           https://npg.si.edu/object/npg_S_NPG.87.222     2025-03-19
# 4           https://npg.si.edu/object/npg_S_NPG.85.297     2025-05-17
# ..                                                 ...            ...
# 152          https://npg.si.edu/object/npg_NPG.2003.72     2025-03-20
# 153         https://npg.si.edu/object/npg_NPG.2002.384     2025-03-19
# 154      https://npg.si.edu/object/npg_NPG.2002.184.62     2025-03-19
# 155       https://npg.si.edu/object/npg_NPG.2002.184.5     2025-03-19
# 156          https://npg.si.edu/object/npg_NPG.2001.13     2025-06-10
#
#                                             creditLine  \
# 0    {"Credit Line": "Smithsonian American Art Muse...
# 1    {"Credit Line": "Smithsonian American Art Muse...
# 2    {"Credit Line": "Smithsonian American Art Muse...
# 3    {"Credit Line": "National Portrait Gallery, Sm...
# 4    {"Credit Line": "National Portrait Gallery, Sm...
# ..                                                 ...
# 152  {"Credit Line": "National Portrait Gallery, Sm...
# 153  {"Credit Line": "National Portrait Gallery, Sm...
# 154  {"Credit Line": "National Portrait Gallery, Sm...
# 155  {"Credit Line": "National Portrait Gallery, Sm...
# 156  {"Credit Line": "National Portrait Gallery, Sm...
#
#                           date  ...  \
# 0            {"Date": "1803?"}  ...
# 1             {"Date": "1810"}  ...
# 2    {"Date": "ca. 1800-1825"}  ...
# 3             {"Date": "1782"}  ...
# 4             {"Date": "1796"}  ...
# ..                         ...  ...
# 152     {"Date": "c. 1800-04"}  ...
# 153           {"Date": "1798"}  ...
# 154     {"Date": "c. 1803-04"}  ...
# 155     {"Date": "c. 1803-04"}  ...
# 156           {"Date": "1796"}  ...
#
#                                          indexed_names indexed_object_types  \
# 0        ['Washington, George', 'Winstanley, William']          [Paintings]
# 1          ['Washington, George', 'Gridley, Enoch G.']       [Graphic arts]
# 2    ['Washington, George', 'Fiquet, H.', 'Trumbull...       [Graphic arts]
# 3               ['Franklin, Benjamin', 'Pelicier, J.']       [Maps, Prints]
# 4    ['Du Simitiere, Pierre Eugene', United States....             [Prints]
# ..                                                 ...                  ...
# 152  ['Graham, George', United States. Army, 'Hamil...             [Prints]
# 153  [United States. Army, 'Washington, George', 'E...             [Prints]
# 154            ['Jefferson, Thomas', 'Bache, William']        [Silhouettes]
# 155  [United States. Army, 'Washington, George', 'B...        [Silhouettes]
# 156  [United States. Army, 'Washington, George', 'S...          [Paintings]
#
#                                         indexed_places  \
# 0                                                   []
# 1                                         [Washington]
# 2                                                   []
# 3                                                   []
# 4                                      [United States]
# ..                                                 ...
# 152                                                 []
# 153                                    [United States]
# 154                          [United States, Virginia]
# 155                                    [United States]
# 156  [Franklin, United States, North America, Germa...
#
#                                         indexed_topics mediaCount  \
# 0    [Occupations, Men, Portraits, Political, Presi...          1
# 1    [Soldiers, Memorials, Occupations, Men, Monume...          1
# 2    [Uniforms, Landscapes, Animals, Occupations, C...          1
# 3    [Social Welfare and Reform, Business and Finan...          1
# 4    [Business and Finance, Congressional Gold Meda...          1
# ..                                                 ...        ...
# 152  [Legislators, Books and reading, Arts and Cult...          1
# 153  [Office, Business and Finance, Natural resourc...          1
# 154  [Business and Finance, Legislators, Cut-out, A...          1
# 155  [Business and Finance, Congressional Gold Meda...          1
# 156  [Business and Finance, Books and reading, Pape...          1
#
#                                              mediaURLs  \
# 0    ['https://ids.si.edu/ids/deliveryService?id=SA...
# 1    ['https://ids.si.edu/ids/deliveryService?id=SA...
# 2    ['https://ids.si.edu/ids/deliveryService?id=SA...
# 3    ['https://ids.si.edu/ids/deliveryService?id=NP...
# 4    ['https://ids.si.edu/ids/deliveryService?id=NP...
# ..                                                 ...
# 152  ['https://ids.si.edu/ids/deliveryService?id=NP...
# 153  ['https://ids.si.edu/ids/deliveryService?id=NP...
# 154  ['https://ids.si.edu/ids/deliveryService?id=NP...
# 155  ['https://ids.si.edu/ids/deliveryService?id=NP...
# 156  ['https://ids.si.edu/ids/deliveryService?id=NP...
#
#                                              thumbnail              Sitter  \
# 0    https://ids.si.edu/ids/iiif/SAAM-XX108A_1/full...   George Washington
# 1    https://ids.si.edu/ids/iiif/SAAM-1971.111_1/fu...   George Washington
# 2    https://ids.si.edu/ids/iiif/SAAM-1971.102_1/fu...   George Washington
# 3    https://ids.si.edu/ids/iiif/NPG-S_NPG_87_222/f...   Benjamin Franklin
# 4    https://ids.si.edu/ids/iiif/NPG-S-NPG_85_297/f...   George Washington
# ..                                                 ...                 ...
# 152  https://ids.si.edu/ids/iiif/NPG-NPG_2003_72Ham...  Alexander Hamilton
# 153  https://ids.si.edu/ids/iiif/NPG-NPG_2002_384/f...   George Washington
# 154  https://ids.si.edu/ids/iiif/NPG-NPG_2002_184_6...    Thomas Jefferson
# 155  https://ids.si.edu/ids/iiif/NPG-NPG_2002_184_5...   George Washington
# 156  https://ids.si.edu/ids/iiif/NPG-NPG_2001_13_ex...   George Washington
#
#                    Artist Clean_Date
# 0      William Winstanley       1803
# 1        Enoch G. Gridley       1810
# 2                     NaN       1800
# 3             J. Pelicier       1782
# 4    Louis Charles Ruotte       1796
# ..                    ...        ...
# 152         George Graham       1800
# 153           David Edwin       1798
# 154         William Bache       1803
# 155         William Bache       1803
# 156        Gilbert Stuart       1796
#
# [157 rows x 29 columns]

# %%
cleaned_test.to_csv("cleaned_test.csv")

# %%
#testing if pandas can read the data
readable = pd.read_csv("cleaned_test.csv")
readable_from_github = pd.read_csv("https://raw.githubusercontent.com/nmolnar-parsons/major-studio-1/refs/heads/main/Project_2/Data/cleaned_test.csv")
